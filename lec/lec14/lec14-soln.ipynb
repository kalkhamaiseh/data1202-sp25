# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# # Lecture 14

# %% [markdown]
# ## Random Sampling ##

# %% [markdown]
# We load in a dataset of all United flights national flights from 6/1/15 to 8/9/15, their destination and how long they were delayed, in minutes.

# %%
united = Table.read_table('united.csv')
united = united.with_column('Row', np.arange(united.num_rows)).move_to_start('Row')
united
# Out:
# Row  | Date   | Flight Number | Destination | Delay
# 0    | 6/1/15 | 73            | HNL         | 257
# 1    | 6/1/15 | 217           | EWR         | 28
# 2    | 6/1/15 | 237           | STL         | -3
# 3    | 6/1/15 | 250           | SAN         | 0
# 4    | 6/1/15 | 267           | PHL         | 64
# 5    | 6/1/15 | 273           | SEA         | -6
# 6    | 6/1/15 | 278           | SEA         | -8
# 7    | 6/1/15 | 292           | EWR         | 12
# 8    | 6/1/15 | 300           | HNL         | 20
# 9    | 6/1/15 | 317           | IND         | -10
# ... (13815 rows omitted)

# %% [markdown]
# Some deterministic samples:

# %%
united.where('Destination', 'JFK')
# Out:
# Row  | Date   | Flight Number | Destination | Delay
# 26   | 6/1/15 | 502           | JFK         | -4
# 33   | 6/1/15 | 637           | JFK         | 141
# 39   | 6/1/15 | 704           | JFK         | -8
# 50   | 6/1/15 | 758           | JFK         | -5
# 51   | 6/1/15 | 760           | JFK         | 352
# 56   | 6/1/15 | 824           | JFK         | 3
# 57   | 6/1/15 | 898           | JFK         | 290
# 179  | 6/2/15 | 502           | JFK         | 0
# 188  | 6/2/15 | 637           | JFK         | 202
# 194  | 6/2/15 | 704           | JFK         | -11
# ... (593 rows omitted)

# %%
united.take(np.arange(0, united.num_rows, 1000))
# Out:
# Row  | Date    | Flight Number | Destination | Delay
# 0    | 6/1/15  | 73            | HNL         | 257
# 1000 | 6/7/15  | 1692          | EWR         | 7
# 2000 | 6/14/15 | 824           | JFK         | -1
# 3000 | 6/21/15 | 217           | EWR         | 5
# 4000 | 6/27/15 | 1401          | SAN         | -4
# 5000 | 7/4/15  | 1614          | LAS         | -2
# 6000 | 7/11/15 | 401           | CLE         | 4
# 7000 | 7/17/15 | 1645          | IAD         | 0
# 8000 | 7/24/15 | 624           | ORD         | 61
# 9000 | 7/30/15 | 1728          | ORD         | 209
# ... (4 rows omitted)

# %%
united.take(make_array(34, 6321, 10040))
# Out:
# Row   | Date    | Flight Number | Destination | Delay
# 34    | 6/1/15  | 650           | AUS         | 44
# 6321  | 7/13/15 | 1124          | SEA         | -7
# 10040 | 8/6/15  | 1216          | LAS         | 2

# %% [markdown]
# A random sample:

# %%
start = np.random.choice(np.arange(1000))
systematic_sample = united.take(np.arange(start, united.num_rows, 1000))
systematic_sample.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Row</th> <th>Date</th> <th>Flight Number</th> <th>Destination</th> <th>Delay</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>10   </td> <td>6/1/15 </td> <td>318          </td> <td>DEN        </td> <td>29   </td>
#         </tr>
#         <tr>
#             <td>1010 </td> <td>6/7/15 </td> <td>1748         </td> <td>SEA        </td> <td>2    </td>
#         </tr>
#         <tr>
#             <td>2010 </td> <td>6/14/15</td> <td>1120         </td> <td>IAH        </td> <td>10   </td>
#         </tr>
#         <tr>
#             <td>3010 </td> <td>6/21/15</td> <td>309          </td> <td>IAD        </td> <td>0    </td>
#         </tr>
#         <tr>
#             <td>4010 </td> <td>6/27/15</td> <td>1564         </td> <td>LAS        </td> <td>-1   </td>
#         </tr>
#         <tr>
#             <td>5010 </td> <td>7/4/15 </td> <td>1723         </td> <td>KOA        </td> <td>-12  </td>
#         </tr>
#         <tr>
#             <td>6010 </td> <td>7/11/15</td> <td>526          </td> <td>DEN        </td> <td>-3   </td>
#         </tr>
#         <tr>
#             <td>7010 </td> <td>7/17/15</td> <td>1686         </td> <td>DCA        </td> <td>37   </td>
#         </tr>
#         <tr>
#             <td>8010 </td> <td>7/24/15</td> <td>758          </td> <td>JFK        </td> <td>18   </td>
#         </tr>
#         <tr>
#             <td>9010 </td> <td>7/30/15</td> <td>1914         </td> <td>IAH        </td> <td>10   </td>
#         </tr>
#         <tr>
#             <td>10010</td> <td>8/6/15 </td> <td>753          </td> <td>DEN        </td> <td>9    </td>
#         </tr>
#         <tr>
#             <td>11010</td> <td>8/12/15</td> <td>1681         </td> <td>PHL        </td> <td>-6   </td>
#         </tr>
#         <tr>
#             <td>12010</td> <td>8/19/15</td> <td>824          </td> <td>JFK        </td> <td>-4   </td>
#         </tr>
#         <tr>
#             <td>13010</td> <td>8/26/15</td> <td>753          </td> <td>DEN        </td> <td>-2   </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <br><br><br><br>
#
# ---
#
# <center> return to slides </center>
#
# ---
#
# <br><br>

# %% [markdown]
# ## Distributions ##

# %%
die = Table().with_column('Face', np.arange(1, 7))
die
# Out:
# Face
# 1
# 2
# 3
# 4
# 5
# 6

# %%
die.sample(10)
# Out:
# Face
# 2
# 5
# 4
# 1
# 4
# 4
# 3
# 5
# 5
# 3

# %%
die.hist()

# %%
roll_bins = np.arange(0.5, 6.6, 1)

# %%
die.hist(bins=roll_bins)

# %%
die.sample(10).hist(bins=roll_bins)

# %%
die.sample(1000).hist(bins=roll_bins)

# %%
die.sample(100000).hist(bins=roll_bins)

# %% [markdown]
# <br><br><br><br>
#
# ---
#
# <center> return to slides </center>
#
# ---
#
# <br><br>

# %% [markdown]
# ## Large Random Samples ##

# %%
united
# Out:
# Row  | Date   | Flight Number | Destination | Delay
# 0    | 6/1/15 | 73            | HNL         | 257
# 1    | 6/1/15 | 217           | EWR         | 28
# 2    | 6/1/15 | 237           | STL         | -3
# 3    | 6/1/15 | 250           | SAN         | 0
# 4    | 6/1/15 | 267           | PHL         | 64
# 5    | 6/1/15 | 273           | SEA         | -6
# 6    | 6/1/15 | 278           | SEA         | -8
# 7    | 6/1/15 | 292           | EWR         | 12
# 8    | 6/1/15 | 300           | HNL         | 20
# 9    | 6/1/15 | 317           | IND         | -10
# ... (13815 rows omitted)

# %%
united_bins = np.arange(-20, 201, 5)
united.hist('Delay', bins = united_bins)

# %%
min(united.column('Delay'))
# Out:
# -16

# %%
max(united.column('Delay'))
# Out:
# 580

# %%
np.average(united.column('Delay'))
# Out:
# 16.658155515370705

# %%
united.sample(10).hist('Delay', bins = united_bins)

# %%
united.sample(1000).hist('Delay', bins = united_bins)

# %% [markdown]
# <br><br><br><br>
#
# ---
#
# <center> return to slides </center>
#
# ---
#
# <br><br>

# %% [markdown]
# ## Simulating Statistics ##

# %%
np.median(united.column('Delay'))
# Out:
# 2.0

# %%
np.median(united.sample(10).column('Delay'))
# Out:
# 4.5

# %%
def sample_median(size):
    return np.median(united.sample(size).column('Delay'))

# %%
# Run this multiple times to see how the median changes over different random samples 
sample_median(10)
# Out:
# 1.0

# %%
sample_medians = make_array()

for i in np.arange(1000):
    new_median = sample_median(10)
    sample_medians = np.append(sample_medians, new_median)

# %%
Table().with_column('Sample medians', sample_medians).hist(bins = np.arange(-10,31))

# %%
sample_medians = make_array()

for i in np.arange(1000):
    new_median = sample_median(1000)
    sample_medians = np.append(sample_medians, new_median)

# %%
Table().with_column(
    'Sample medians', sample_medians).hist(bins = np.arange(-10,31))
